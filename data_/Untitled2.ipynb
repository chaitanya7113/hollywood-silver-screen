# %%
import pickle

# %%
pickle.dump(movies_data.to_dict(),open('movies_data.pkl','wb'))

# %%
import pandas as pd
import numpy as np

# %%
movies_data=pd.read_csv('movies_data.csv')

# %%
movies_data
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4804      9367                               El Mariachi
# 4805     72766                                 Newlyweds
# 4806    231617                 Signed, Sealed, Delivered
# 4807    126186                          Shanghai Calling
# 4808     25975                         My Date with Drew
#
#                                                  genres  \
# 0     ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 1                    ['Adventure', 'Fantasy', 'Action']
# 2                      ['Action', 'Adventure', 'Crime']
# ...

# %%
index_=movies_data[movies_data['title']=='Avatar'].index[0]

# %%
id=movies_data.iloc[index_]['movie_id']

# %%
id
# Out:
# 19995

# %%
genres = movies_data[movies_data['title'] == 'Avatar']['genres'].values[0]

# %%
genres
# Out:
# "['Action', 'Adventure', 'Fantasy', 'Science Fiction']"
